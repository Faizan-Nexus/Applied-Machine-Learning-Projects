# %%
import pandas as pd
data = pd.read_csv('Marks.csv', sep='t')
print(data.iloc[1:5])
# Out:
#     Sr No.,Roll No:,Ma  hs,Physics,Comp,English
# 1  2,IBA_2,50,92,94,95                      NaN
# 2  3,IBA_3,54,91,63,98                      NaN
# 3  4,IBA_4,70,43,71,50                      NaN
# 4  5,IBA_5,58,86,66,62                      NaN
